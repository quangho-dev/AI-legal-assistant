# %%
import pandas as pd

# %%
df = pd.read_csv("/Users/admin/Documents/Personal projects/New AI legal assistant/evals/experiments/20260501-152827_naiverag.csv")
print(df.head())
# Out:
#                                             question  \
# 0  Hôm nay, Linh có thư nhưng Linh nghỉ ốm nên cô...
# 1  Mùa mưa bão sắp tới, lo sợ cây bên nhà hàng xó...
# 2  H là người nghiện ma túy lâu năm, mỗi khi khôn...
# 3  Vợ chồng ông bà X không may qua đời vì bị tai ...
# 4  Xin cho biết, pháp luật dân sự quy định như th...
#
#                                      expected_answer  \
# 0  Điều 38 Bộ luật dân sự năm 2015 quy định về qu...
# 1  Điều 177 Bộ luật dân sự quy định về bảo đảm an...
# 2  Theo Điều 24 Bộ luật dân sự thì một cá nhân bị...
# 3  Theo quy định tại khoản 1 Điều 611 Bộ luật dân...
# 4  Theo quy định tại Điều 173 Bộ luật dân sự năm ...
#
#                                       model_response  correctness_score  \
# 0  Theo quy định pháp luật, hành động của Nga là ...                  1
# 1  Dựa trên bối cảnh đã cung cấp, bạn có quyền yê...                  1
# 2  Có, theo ngữ cảnh được cung cấp, H có thể bị T...                  1
# ...

# %%
print(df.columns)
# Out:
# Index(['question', 'expected_answer', 'model_response', 'correctness_score',
#        'correctness_reason', 'faithfulness_score', 'faithfulness_reason',
#        'answer_relevancy_score', 'answer_relevancy_reason',
#        'context_precision_score', 'context_precision_reason',
#        'context_recall_score', 'context_recall_reason', 'mlflow_trace_id',
#        'mlflow_trace_url', 'retrieved_documents'],
#       dtype='object')

# %%
cols = [
    "correctness_score",
    "faithfulness_score",
    "answer_relevancy_score",
    "context_precision_score",
    "context_recall_score"
]

averages = df[cols].mean()

print(averages)
# Out:
# correctness_score          0.648649
# faithfulness_score         0.614335
# answer_relevancy_score     0.425195
# context_precision_score    0.949700
# context_recall_score       0.802660
# dtype: float64

# %%
agentic = pd.read_csv("/Users/admin/Documents/Personal projects/New AI legal assistant/evals/experiments/20260504-213949_agenticrag.csv")

print(agentic.columns)
# Out:
# Index(['question', 'expected_answer', 'model_response', 'correctness_score',
#        'correctness_reason', 'faithfulness_score', 'faithfulness_reason',
#        'answer_relevancy_score', 'answer_relevancy_reason',
#        'context_precision_score', 'context_precision_reason',
#        'context_recall_score', 'context_recall_reason', 'mlflow_trace_url',
#        'retrieved_documents'],
#       dtype='object')

# %%
cols = [
    "correctness_score",
    "faithfulness_score",
    "answer_relevancy_score",
    "context_precision_score",
    "context_recall_score"
]

averages = agentic_df[cols].mean()

print(averages)
# Out:
# correctness_score          0.421053
# faithfulness_score         0.850710
# answer_relevancy_score     0.478428
# context_precision_score    0.938596
# context_recall_score       0.730159
# dtype: float64

# %%
pd.set_option('display.max_colwidth', None)

print(agentic["mlflow_trace_url"])
# Out:
# 0    http://localhost:5000/#/experiments/Exp/traces?selectedTraceId=None
# 1    http://localhost:5000/#/experiments/Exp/traces?selectedTraceId=None
# Name: mlflow_trace_url, dtype: object
